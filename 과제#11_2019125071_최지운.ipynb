# %% [markdown]
# # 0. 오늘은 Regression 문제를 풀어 볼 예정입니다.
#
#  - 오늘의 목표는 sin 함수를 예측해보는 RNN 모델을 만드는 것입니다.

# %% [markdown]
# ## 1.우선 필요 라이브러리를 import 합니다.

# %%
import numpy as np 
import matplotlib.pyplot as plt

import torch
from torch.utils import data

import torch.optim as optim

# %% [markdown]
# ## 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 2.0.0+cpu  Device: cpu

# %% [markdown]
# # 3. Data를 만들어 봅시다
#
#  - 입력값은 SIN 함수의 일부인 연속된 5개 값입니다.
#
#  - RNN 모델은 5개의 SIN함수의 일부를 입력받아서 다음 번 숫자를 예측합니다.
#
#  - T는 1주기를 몇개의 값으로 표현했는지는 나타냅니다.
#
#  - n은 몇번의 주기를 만들지 표현합니다.
#
#  - amp 는 sin함수의 크기를 나타냅니다.
#
#  - alpha 는 시작점의 위치를 나타냅니다.

# %%
def sin_data(x, T=100):
    return np.sin((2*np.pi)/T * x)

def toy_problem(n = 3, T=100, amp = 3, alpha = 0):
    x = np.arange(0, n*T + 1) + alpha
    return amp*sin_data(x, T)

# %%
plt.plot(toy_problem(5))
plt.show()

# %% [markdown]
#  - sin_dataset: 새로운 데이터를 모델에 입력하기 위해 Dataset를 정의합니다.
#
#  - prepare_data: 입력은 n, T, alpha를 받습니다. 출력은 sin 함수의 연속된 값을 5개씩으로 데이터를 만들고 이에 대한 label을 sin함수의 6번째 값으로 지정합니다.

# %%
class sin_dataset(data.Dataset):
    def __init__(self, r_data, label):
        self.r_data = r_data.unsqueeze(-1)
        self.label = label
    
    def __len__(self):
        return len(self.r_data)
    
    def __getitem__(self,index):
        return self.r_data[index], self.label[index]

def prepare_data(n,T, alpha=0):
    target = toy_problem(n=n, T=T, amp=3, alpha=0)
    plt.plot(target)
    plt.show()
    
    rd = []
    labels = []
    
    for i in range(T*n - 5):
        rd.append(target[i:i+5])
        labels.append(target[i+5])
    
    return torch.Tensor(rd), torch.Tensor(labels)

# %% [markdown]
# - train, validation, test 데이터셋을 만들고 이를 DataLoader에 입력합니다.

# %%
BATCH_SIZE = 10
T = 200
n = 5

pre_train = prepare_data(n,T)
pre_test = prepare_data(int(n/4),T,n+1)

train = sin_dataset(pre_train[0], pre_train[1])
test = sin_dataset(pre_test[0], pre_test[1])

train, val = data.random_split(train, [int(len(train) * 0.7), len(train) - int(len(train) * 0.7)])

train_loader = torch.utils.data.DataLoader(dataset=train, batch_size=BATCH_SIZE, shuffle=False)
val_loader = torch.utils.data.DataLoader(dataset=val, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_2404\2709095698.py:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   return torch.Tensor(rd), torch.Tensor(labels)

# %% [markdown]
# # 4.모델 만들기
#
#
# 아래의 모델에서 many-to-one RNN 모델을 만들어봅시다.
#
#  - RNN의 Hidden Unit의 수는 100으로 하세요
#
#  - RNN의 입력의 크기는 5개입니다. 즉, 5개의 입력값으로 6번째 값을 예측해 봅시다.
#
#  - 활성화 함수는 ReLU로 하세요.
#
# ![RNN.png](attachment:RNN.png)

# %%
import torch.nn as nn

class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        self.rnn = nn.RNN(input_size = 1, hidden_size = 100, batch_first = True) 
        self.relu = nn.ReLU()
        self.fc = nn.Linear(100, 1)
        
    def forward(self, x, h_state):
        
        out, h_state = self.rnn(x, h_state)
        out = self.relu(out)
        out = self.fc(out)
        
        return out[:,-1].squeeze() # 마지막 RNN 층의 출력값만 사용함

# %% [markdown]
# ## 7. 학습 준비하기
#
# 1) 1 epoch를 학습할 수 있는 함수 만들기
#
# 2) Test와 Validation data의 정확도 계산할 수 있는 함수 만들기

# %%
def training_epoch(train_loader, network, loss_func, optimizer, epoch):
    train_losses = []
    train_correct = 0
    log_interval = 300
    
    for batch_idx, (r_data, label) in enumerate(train_loader):
        r_data, label = r_data.to(device), label.to(device)

        # 미분값의 초기화
        optimizer.zero_grad()

        # Forward propagration 계산하기.
        init_h = torch.zeros(1, r_data.size()[0], 100)
        outputs = network(r_data, init_h)
        
        
        # MSE 함수를 적용하여 loss를 구하고 저장하기
        loss = loss_func(outputs, label)
        train_losses.append(loss.item())

        # Gradinet 구하기
        loss.backward()

        # weight값 update 하기
        optimizer.step()

        # 학습 상황 출력
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.2f}%)]\tLoss: {:.6f}'
                  .format(epoch, batch_idx * len(label), len(train_loader.dataset),100. * batch_idx / len(train_loader),
                          loss.item()))
            
    return train_losses

# %%
def test_epoch(test_loader, network, loss_func, val = False):
    correct = 0
    
    test_losses = []
    
    with torch.no_grad():
        for batch_idx, (image, label) in enumerate(test_loader):
            image, label = image.to(device), label.to(device)

            # Forward propagration 계산하기.
            init_h = torch.zeros(1, image.size()[0], 100)
            outputs = network(image, init_h)

            # MSE 함수를 적용하여 loss를 구하기
            loss = loss_func(outputs, label)
            test_losses.append(loss.item())


        #중간결과 출력
        if val is True:
            print('Validation set: Loss: {:.5f}\n'.format(loss))
        
        else:
            print('Test set: Loss: {:.5f}\n'.format(loss))
        
    return test_losses

# %% [markdown]
# ## 8. 위 정의된 함수로 학습 함수 만들기
#
# - Adam Optimizer를 사용하여 학습시키기
#
# - MSELoss() 함수를 사용할 것

# %%
def training(network, learning_rate = 0.001):
    
    epoches = 100
    
    cls_loss = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(network.parameters(), lr = learning_rate)
    
    train_losses_per_epoch = []
    test_losses_per_epoch = []
  
    for epoch in range(epoches):
                
        # 모델를 학습 중이라고 선언하기
        network.train()
        
        train_losses = training_epoch(train_loader,network,cls_loss,optimizer, epoch)
        
        # epoch 별로 loss 평균값, 정확도 구하기
        average_loss = np.mean(train_losses)
        train_losses_per_epoch.append(average_loss)
        
        
        # epoch 별로 정확도 출력
        print('\nTraining set: Loss {:.6f}'.format(average_loss))

        
        ### 학습 중에 test 결과 보기
        
        # 모델 test 중인 것을 선언하기
        network.eval()
        
        correct = 0
        with torch.no_grad():
            test_losses = test_epoch(train_loader, network, cls_loss, True)

        test_losses_per_epoch.append(np.mean(test_losses))
        
    with torch.no_grad():
        test_losses = test_epoch(test_loader, network, cls_loss, False)
        
    return train_losses_per_epoch, test_losses_per_epoch

# %%
model = RNN().to(device)
train_loss, test_loss = training(model)
# Out:
# Train Epoch: 0 [0/696 (0.00%)]	Loss: 4.765875
#
# Training set: Loss 0.950398
# Validation set: Loss: 0.09141
#
# Train Epoch: 1 [0/696 (0.00%)]	Loss: 0.239812
#
# Training set: Loss 0.153261
# Validation set: Loss: 0.04396
#
# Train Epoch: 2 [0/696 (0.00%)]	Loss: 0.093347
#
# Training set: Loss 0.070863
# Validation set: Loss: 0.03316
#
# Train Epoch: 3 [0/696 (0.00%)]	Loss: 0.045135
#
# Training set: Loss 0.036898
# Validation set: Loss: 0.02016
#
# Train Epoch: 4 [0/696 (0.00%)]	Loss: 0.029591
#
# Training set: Loss 0.022379
# Validation set: Loss: 0.00949
#
# Train Epoch: 5 [0/696 (0.00%)]	Loss: 0.020058
#
# Training set: Loss 0.017680
# Validation set: Loss: 0.00658
#
# Train Epoch: 6 [0/696 (0.00%)]	Loss: 0.015060
#
# Training set: Loss 0.013512
# Validation set: Loss: 0.00404
#
# Train Epoch: 7 [0/696 (0.00%)]	Loss: 0.010191
#
# Training set: Loss 0.011004
# Validation set: Loss: 0.00306
#
# Train Epoch: 8 [0/696 (0.00%)]	Loss: 0.010185
#
# Training set: Loss 0.009451
# Validation set: Loss: 0.00435
#
# Train Epoch: 9 [0/696 (0.00%)]	Loss: 0.012221
#
# Training set: Loss 0.007931
# Validation set: Loss: 0.00552
#
# Train Epoch: 10 [0/696 (0.00%)]	Loss: 0.013930
#
# Training set: Loss 0.006927
# Validation set: Loss: 0.00562
#
# Train Epoch: 11 [0/696 (0.00%)]	Loss: 0.013545
#
# Training set: Loss 0.006317
# Validation set: Loss: 0.00435
#
# Train Epoch: 12 [0/696 (0.00%)]	Loss: 0.010910
#
# Training set: Loss 0.005805
# Validation set: Loss: 0.00347
#
# Train Epoch: 13 [0/696 (0.00%)]	Loss: 0.008789
#
# Training set: Loss 0.005477
# Validation set: Loss: 0.00318
#
# Train Epoch: 14 [0/696 (0.00%)]	Loss: 0.008158
#
# Training set: Loss 0.005089
# Validation set: Loss: 0.00253
#
# Train Epoch: 15 [0/696 (0.00%)]	Loss: 0.006678
#
# Training set: Loss 0.004663
# Validation set: Loss: 0.00191
#
# Train Epoch: 16 [0/696 (0.00%)]	Loss: 0.005464
#
# Training set: Loss 0.004337
# Validation set: Loss: 0.00189
#
# Train Epoch: 17 [0/696 (0.00%)]	Loss: 0.005159
#
# Training set: Loss 0.004005
# Validation set: Loss: 0.00197
#
# Train Epoch: 18 [0/696 (0.00%)]	Loss: 0.005229
#
# Training set: Loss 0.003886
# Validation set: Loss: 0.00167
#
# Train Epoch: 19 [0/696 (0.00%)]	Loss: 0.004330
#
# Training set: Loss 0.003628
# Validation set: Loss: 0.00163
#
# Train Epoch: 20 [0/696 (0.00%)]	Loss: 0.004125
#
# Training set: Loss 0.003352
# Validation set: Loss: 0.00156
#
# Train Epoch: 21 [0/696 (0.00%)]	Loss: 0.003977
#
# Training set: Loss 0.003144
# Validation set: Loss: 0.00198
#
# Train Epoch: 22 [0/696 (0.00%)]	Loss: 0.004676
#
# Training set: Loss 0.003051
# Validation set: Loss: 0.00164
#
# Train Epoch: 23 [0/696 (0.00%)]	Loss: 0.004112
#
# Training set: Loss 0.002899
# Validation set: Loss: 0.00176
#
# Train Epoch: 24 [0/696 (0.00%)]	Loss: 0.004303
#
# Training set: Loss 0.002623
# Validation set: Loss: 0.00203
#
# Train Epoch: 25 [0/696 (0.00%)]	Loss: 0.004530
#
# Training set: Loss 0.002546
# Validation set: Loss: 0.00189
#
# Train Epoch: 26 [0/696 (0.00%)]	Loss: 0.004298
#
# Training set: Loss 0.002390
# Validation set: Loss: 0.00206
#
# Train Epoch: 27 [0/696 (0.00%)]	Loss: 0.004291
#
# Training set: Loss 0.002329
# Validation set: Loss: 0.00165
#
# Train Epoch: 28 [0/696 (0.00%)]	Loss: 0.003689
#
# Training set: Loss 0.002160
# Validation set: Loss: 0.00161
#
# Train Epoch: 29 [0/696 (0.00%)]	Loss: 0.003502
#
# Training set: Loss 0.001849
# Validation set: Loss: 0.00200
#
# Train Epoch: 30 [0/696 (0.00%)]	Loss: 0.004098
#
# Training set: Loss 0.001724
# Validation set: Loss: 0.00243
#
# Train Epoch: 31 [0/696 (0.00%)]	Loss: 0.004627
#
# Training set: Loss 0.001561
# Validation set: Loss: 0.00277
#
# Train Epoch: 32 [0/696 (0.00%)]	Loss: 0.005029
#
# Training set: Loss 0.001245
# Validation set: Loss: 0.00258
#
# Train Epoch: 33 [0/696 (0.00%)]	Loss: 0.004592
#
# Training set: Loss 0.001054
# Validation set: Loss: 0.00193
#
# Train Epoch: 34 [0/696 (0.00%)]	Loss: 0.003450
#
# Training set: Loss 0.000845
# Validation set: Loss: 0.00106
#
# Train Epoch: 35 [0/696 (0.00%)]	Loss: 0.002080
#
# Training set: Loss 0.000692
# Validation set: Loss: 0.00058
#
# Train Epoch: 36 [0/696 (0.00%)]	Loss: 0.001294
#
# Training set: Loss 0.000605
# Validation set: Loss: 0.00055
#
# Train Epoch: 37 [0/696 (0.00%)]	Loss: 0.001182
#
# Training set: Loss 0.000658
# Validation set: Loss: 0.00088
#
# Train Epoch: 38 [0/696 (0.00%)]	Loss: 0.001568
#
# Training set: Loss 0.000698
# Validation set: Loss: 0.00051
#
# Train Epoch: 39 [0/696 (0.00%)]	Loss: 0.001013
#
# Training set: Loss 0.000680
# Validation set: Loss: 0.00028
#
# Train Epoch: 40 [0/696 (0.00%)]	Loss: 0.000689
#
# Training set: Loss 0.000614
# Validation set: Loss: 0.00006
#
# Train Epoch: 41 [0/696 (0.00%)]	Loss: 0.000349
#
# Training set: Loss 0.000520
# Validation set: Loss: 0.00032
#
# Train Epoch: 42 [0/696 (0.00%)]	Loss: 0.000647
#
# Training set: Loss 0.000466
# Validation set: Loss: 0.00078
#
# Train Epoch: 43 [0/696 (0.00%)]	Loss: 0.001248
#
# Training set: Loss 0.000470
# Validation set: Loss: 0.00132
#
# Train Epoch: 44 [0/696 (0.00%)]	Loss: 0.001910
#
# Training set: Loss 0.000550
# Validation set: Loss: 0.00169
#
# Train Epoch: 45 [0/696 (0.00%)]	Loss: 0.002319
#
# Training set: Loss 0.000645
# Validation set: Loss: 0.00170
#
# Train Epoch: 46 [0/696 (0.00%)]	Loss: 0.002283
#
# Training set: Loss 0.000726
# Validation set: Loss: 0.00179
#
# Train Epoch: 47 [0/696 (0.00%)]	Loss: 0.002276
#
# Training set: Loss 0.000779
# Validation set: Loss: 0.00168
#
# Train Epoch: 48 [0/696 (0.00%)]	Loss: 0.002140
#
# Training set: Loss 0.000790
# Validation set: Loss: 0.00194
#
# Train Epoch: 49 [0/696 (0.00%)]	Loss: 0.002318
#
# Training set: Loss 0.000734
# Validation set: Loss: 0.00169
#
# Train Epoch: 50 [0/696 (0.00%)]	Loss: 0.002079
#
# Training set: Loss 0.000693
# Validation set: Loss: 0.00147
#
# Train Epoch: 51 [0/696 (0.00%)]	Loss: 0.001762
#
# Training set: Loss 0.000655
# Validation set: Loss: 0.00126
#
# Train Epoch: 52 [0/696 (0.00%)]	Loss: 0.001591
#
# Training set: Loss 0.000625
# Validation set: Loss: 0.00135
#
# Train Epoch: 53 [0/696 (0.00%)]	Loss: 0.001574
#
# Training set: Loss 0.000663
# Validation set: Loss: 0.00104
#
# Train Epoch: 54 [0/696 (0.00%)]	Loss: 0.001347
#
# Training set: Loss 0.000638
# Validation set: Loss: 0.00099
#
# Train Epoch: 55 [0/696 (0.00%)]	Loss: 0.001195
#
# Training set: Loss 0.000646
# Validation set: Loss: 0.00082
#
# Train Epoch: 56 [0/696 (0.00%)]	Loss: 0.000879
#
# Training set: Loss 0.000643
# Validation set: Loss: 0.00116
#
# Train Epoch: 57 [0/696 (0.00%)]	Loss: 0.001238
#
# Training set: Loss 0.000638
# Validation set: Loss: 0.00095
#
# Train Epoch: 58 [0/696 (0.00%)]	Loss: 0.000969
#
# Training set: Loss 0.000888
# Validation set: Loss: 0.00063
#
# Train Epoch: 59 [0/696 (0.00%)]	Loss: 0.000951
#
# Training set: Loss 0.000518
# Validation set: Loss: 0.00087
#
# Train Epoch: 60 [0/696 (0.00%)]	Loss: 0.000988
#
# Training set: Loss 0.000503
# Validation set: Loss: 0.00137
#
# Train Epoch: 61 [0/696 (0.00%)]	Loss: 0.001156
#
# Training set: Loss 0.000655
# Validation set: Loss: 0.00171
#
# Train Epoch: 62 [0/696 (0.00%)]	Loss: 0.001624
#
# Training set: Loss 0.000775
# Validation set: Loss: 0.00070
#
# Train Epoch: 63 [0/696 (0.00%)]	Loss: 0.000872
#
# Training set: Loss 0.000665
# Validation set: Loss: 0.00084
#
# Train Epoch: 64 [0/696 (0.00%)]	Loss: 0.001080
#
# Training set: Loss 0.000556
# Validation set: Loss: 0.00124
#
# Train Epoch: 65 [0/696 (0.00%)]	Loss: 0.001207
#
# Training set: Loss 0.000546
# Validation set: Loss: 0.00134
#
# Train Epoch: 66 [0/696 (0.00%)]	Loss: 0.001358
#
# Training set: Loss 0.000712
# Validation set: Loss: 0.00165
#
# Train Epoch: 67 [0/696 (0.00%)]	Loss: 0.001701
#
# Training set: Loss 0.000738
# Validation set: Loss: 0.00061
#
# Train Epoch: 68 [0/696 (0.00%)]	Loss: 0.000733
#
# Training set: Loss 0.000416
# Validation set: Loss: 0.00090
#
# Train Epoch: 69 [0/696 (0.00%)]	Loss: 0.000793
#
# Training set: Loss 0.000430
# Validation set: Loss: 0.00139
#
# Train Epoch: 70 [0/696 (0.00%)]	Loss: 0.001029
#
# Training set: Loss 0.000708
# Validation set: Loss: 0.00078
#
# Train Epoch: 71 [0/696 (0.00%)]	Loss: 0.000944
#
# Training set: Loss 0.000763
# Validation set: Loss: 0.00063
#
# Train Epoch: 72 [0/696 (0.00%)]	Loss: 0.000874
#
# Training set: Loss 0.000491
# Validation set: Loss: 0.00070
#
# Train Epoch: 73 [0/696 (0.00%)]	Loss: 0.000676
#
# Training set: Loss 0.000365
# Validation set: Loss: 0.00108
#
# Train Epoch: 74 [0/696 (0.00%)]	Loss: 0.001014
#
# Training set: Loss 0.000604
# Validation set: Loss: 0.00109
#
# Train Epoch: 75 [0/696 (0.00%)]	Loss: 0.001277
#
# Training set: Loss 0.000691
# Validation set: Loss: 0.00032
#
# Train Epoch: 76 [0/696 (0.00%)]	Loss: 0.000557
#
# Training set: Loss 0.000357
# Validation set: Loss: 0.00091
#
# Train Epoch: 77 [0/696 (0.00%)]	Loss: 0.000768
# Training set: Loss 0.000470
# Validation set: Loss: 0.00098
#
# Train Epoch: 78 [0/696 (0.00%)]	Loss: 0.001167
#
# Training set: Loss 0.000718
# Validation set: Loss: 0.00009
#
# Train Epoch: 79 [0/696 (0.00%)]	Loss: 0.000429
#
# Training set: Loss 0.000491
# Validation set: Loss: 0.00065
#
# Train Epoch: 80 [0/696 (0.00%)]	Loss: 0.000712
#
# Training set: Loss 0.000332
# Validation set: Loss: 0.00113
#
# Train Epoch: 81 [0/696 (0.00%)]	Loss: 0.001063
#
# Training set: Loss 0.000583
# Validation set: Loss: 0.00043
#
# Train Epoch: 82 [0/696 (0.00%)]	Loss: 0.000691
#
# Training set: Loss 0.000577
# Validation set: Loss: 0.00093
#
# Train Epoch: 83 [0/696 (0.00%)]	Loss: 0.001084
#
# Training set: Loss 0.000454
# Validation set: Loss: 0.00081
#
# Train Epoch: 84 [0/696 (0.00%)]	Loss: 0.000933
#
# Training set: Loss 0.000451
# Validation set: Loss: 0.00067
#
# Train Epoch: 85 [0/696 (0.00%)]	Loss: 0.000827
#
# Training set: Loss 0.000657
# Validation set: Loss: 0.00027
#
# Train Epoch: 86 [0/696 (0.00%)]	Loss: 0.000484
#
# Training set: Loss 0.000390
# Validation set: Loss: 0.00060
#
# Train Epoch: 87 [0/696 (0.00%)]	Loss: 0.000541
#
# Training set: Loss 0.000308
# Validation set: Loss: 0.00081
#
# Train Epoch: 88 [0/696 (0.00%)]	Loss: 0.000838
#
# Training set: Loss 0.000481
# Validation set: Loss: 0.00020
#
# Train Epoch: 89 [0/696 (0.00%)]	Loss: 0.000394
#
# Training set: Loss 0.000513
# Validation set: Loss: 0.00087
#
# Train Epoch: 90 [0/696 (0.00%)]	Loss: 0.000558
#
# Training set: Loss 0.000262
# Validation set: Loss: 0.00063
#
# Train Epoch: 91 [0/696 (0.00%)]	Loss: 0.000431
#
# Training set: Loss 0.000330
# Validation set: Loss: 0.00098
#
# Train Epoch: 92 [0/696 (0.00%)]	Loss: 0.001090
#
# Training set: Loss 0.000532
# Validation set: Loss: 0.00153
#
# Train Epoch: 93 [0/696 (0.00%)]	Loss: 0.001521
#
# Training set: Loss 0.000510
# Validation set: Loss: 0.00069
#
# Train Epoch: 94 [0/696 (0.00%)]	Loss: 0.000377
#
# Training set: Loss 0.000160
# Validation set: Loss: 0.00033
#
# Train Epoch: 95 [0/696 (0.00%)]	Loss: 0.000133
#
# Training set: Loss 0.000141
# Validation set: Loss: 0.00059
#
# Train Epoch: 96 [0/696 (0.00%)]	Loss: 0.000390
#
# Training set: Loss 0.000127
# Validation set: Loss: 0.00024
#
# Train Epoch: 97 [0/696 (0.00%)]	Loss: 0.000140
#
# Training set: Loss 0.000078
# Validation set: Loss: 0.00004
#
# Train Epoch: 98 [0/696 (0.00%)]	Loss: 0.000034
#
# Training set: Loss 0.000075
# Validation set: Loss: 0.00005
#
# Train Epoch: 99 [0/696 (0.00%)]	Loss: 0.000107
#
# Training set: Loss 0.000088
# Validation set: Loss: 0.00006
#
# Test set: Loss: 0.00000

# %%
plt.plot(train_loss)
plt.plot(test_loss)

# %% [markdown]
#  ## 9. RNN함수가 얼마나 잘 학습 되었는지 확인해 봅시다.
#
#   - 초기값은 sin함수 1주기 후 마지막 5개 값으로 하고
#
#   - 이를 바탕으로 6번째 예측을 한 후
#
#   - 다시 새롭게 추가된 값으로부터 마지막 5개를 새로운 입력으로 하여
#
#   - 100 번째 값까지 예측해봅시다.

# %%
init_test = toy_problem(1,T, amp=3)
init_test = torch.tensor(init_test[-5:].reshape(1,5,1), dtype=torch.float).cpu()

# %%
h_state = torch.zeros(1,1,100).cpu()


for i in range(3000):
    model = model.cpu()
    init_test = torch.tensor(init_test, dtype=torch.float).cpu()
    r = model(init_test[-5:].reshape(1,5,1), h_state).clone().detach().item()
    
    init_test = np.concatenate((init_test.clone().detach().numpy().squeeze(),r), axis=None)
 
    
plt.plot(init_test[5:])
print(2019125071)

plt.plot(toy_problem(15,T,amp=3))
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_2404\2727151610.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   init_test = torch.tensor(init_test, dtype=torch.float).cpu()
# 2019125071

# %% [markdown]
# ## 10. 잘 예측이 됩니까? 안된다면 이유가 무엇일까요? 사인함수의 예측에 RNN 모델을 사용하는 것이 좋은 선택일까요?

# %% [markdown]
# 정답)
# 손실값 결과를 보면 사인 함수 예측에 RNN모델을 사용해
#      도 좋은 결과를 도출할 수 있다고 생각된다. 좀 더 탐구해본 바로는 RNN에서는 이전 출력값이
#      다음 입력값이 되는 순환구조이기 때문에 이전 값들이 계속 커질수록 전체 결과가 발산하게 될
#      수 있기에 활성화삼수로 ReLu를 사용하는 것은 적합하지 않은 선택일 수도 있다.
